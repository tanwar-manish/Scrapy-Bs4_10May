# %%
import requests
from bs4 import BeautifulSoup

url='https://webscraper.io/test-sites/e-commerce/static/computers/tablets'

response = requests.get(url)
response
soup=BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>Static | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords">
# ...

# %%
import requests
from bs4 import BeautifulSoup

url='https://webscraper.io/test-sites/e-commerce/static/computers/tablets'

response = requests.get(url)
response
soup=BeautifulSoup(response.content, 'html.parser')
#soup


all_product_details = soup.find_all('div', class_='card thumbnail')

for details in all_product_details:
    product_name = details.find('a', class_='title').text
    
    product_price = details.find('h4', class_='price float-end card-title pull-right').text
    
    review_count = details.find('p', class_='review-count float-end').text.strip().split()[0]
    rating = len(details.find_all('span', class_='ws-icon ws-icon-star'))

    print(f"Product Name: {product_name}")
    print(f"Product Price: {product_price}")
    print(f"Review Count: {review_count}")
    print(f"Rating: {rating} stars")
    print()
# Out:
# Product Name: Lenovo IdeaTab
# Product Price: $69.99
# Review Count: 7
# Rating: 3 stars
#
# Product Name: Acer Iconia
# Product Price: $96.99
# Review Count: 7
# Rating: 1 stars
#
# Product Name: Asus MeMO Pad
# Product Price: $102.99
# Review Count: 14
# Rating: 4 stars
#
# Product Name: Amazon Kindle
# Product Price: $103.99
# Review Count: 3
# Rating: 4 stars
#
# Product Name: iPad Mini Reti...
# Product Price: $537.99
# Review Count: 8
# Rating: 2 stars
#
# Product Name: IdeaTab A3500L
# Product Price: $88.99
# Review Count: 7
# Rating: 4 stars

# %%
import requests
from bs4 import BeautifulSoup

def scrape_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    all_product_details = soup.find_all('div', class_='card thumbnail')

    for details in all_product_details:
        product_name = details.find('a', class_='title').text
    
        product_price = details.find('h4', class_='price float-end card-title pull-right').text

        review_count = details.find('p', class_='review-count float-end').text.strip().split()[0]
        rating = len(details.find_all('span', class_='ws-icon ws-icon-star'))

        print(f"Product Name: {product_name}")
        print(f"Product Price: {product_price}")
        print(f"Review Count: {review_count}")
        print(f"Rating: {rating} stars")
        print()

url = 'https://webscraper.io/test-sites/e-commerce/static/computers/tablets'

for i in range(5):
    next_page_url = f'{url}?page={i}'
    response = requests.get(next_page_url)
    if response.status_code == 200:
        scrape_page(next_page_url)
        i+=1
# Out:
# Product Name: Lenovo IdeaTab
# Product Price: $69.99
# Review Count: 7
# Rating: 3 stars
#
# Product Name: Acer Iconia
# Product Price: $96.99
# Review Count: 7
# Rating: 1 stars
#
# Product Name: Asus MeMO Pad
# Product Price: $102.99
# Review Count: 14
# Rating: 4 stars
#
# Product Name: Amazon Kindle
# Product Price: $103.99
# Review Count: 3
# Rating: 4 stars
#
# Product Name: iPad Mini Reti...
# Product Price: $537.99
# Review Count: 8
# Rating: 2 stars
#
# Product Name: IdeaTab A3500L
# Product Price: $88.99
# Review Count: 7
# Rating: 4 stars
#
# Product Name: Lenovo IdeaTab
# Product Price: $69.99
# Review Count: 7
# Rating: 3 stars
#
# Product Name: Acer Iconia
# Product Price: $96.99
# Review Count: 7
# Rating: 1 stars
#
# Product Name: Asus MeMO Pad
# Product Price: $102.99
# Review Count: 14
# Rating: 4 stars
#
# Product Name: Amazon Kindle
# Product Price: $103.99
# Review Count: 3
# Rating: 4 stars
#
# Product Name: iPad Mini Reti...
# Product Price: $537.99
# ...
